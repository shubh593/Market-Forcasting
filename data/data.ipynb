# %%
import pandas as pd

# %%
df=pd.read_json("market_history.json")

# %%
df
# Out:
#                     fetched_at  \
# 0   2026-01-09 12:33:28.182744
# 1   2026-01-09 12:34:28.747715
# 2   2026-01-09 12:35:29.350079
# 3   2026-01-09 12:36:29.748994
# 4   2026-01-09 12:37:30.342137
# ..                         ...
# 446 2026-01-12 07:36:41.979107
# 447 2026-01-12 07:37:42.684346
# 448 2026-01-12 07:38:43.018293
# 449 2026-01-12 07:39:43.596088
# 450 2026-01-12 07:40:44.347923
#
#                                                   data
# 0    {'result': {'contract_value': '0.0010000000000...
# 1    {'result': {'contract_value': '0.0010000000000...
# 2    {'result': {'contract_type': 'perpetual_future...
# 3    {'result': {'contract_value': '0.0010000000000...
# 4    {'result': {'contract_type': 'perpetual_future...
# ..                                                 ...
# 446  {'result': {'contract_type': 'perpetual_future...
# 447  {'result': {'contract_type': 'perpetual_future...
# 448  {'result': {'contract_value': '0.0010000000000...
# ...
